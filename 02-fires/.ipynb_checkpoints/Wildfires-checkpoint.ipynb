# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait

# %%
# driver = webdriver.Chrome()
# driver.get('https://www.nifc.gov/fireInfo/fireInfo_stats_totalFires.html')

# %%
# fire = driver.find_element_by_tag_name('tbody')
# print(fire)

# %%
# fire.text

# %%
# rows = fire.find_elements_by_tag_name('tr')[3:-1]
# table = []
# for row in rows:
#     annual_fires = {}
#     annual_fires['year'] = row.find_elements_by_tag_name('td')[0].text
#     print(annual_fires['year'])
#     annual_fires['fires'] = row.find_elements_by_tag_name('td')[1].text
#     print(annual_fires['fires'])
#     annual_fires['acres'] = row.find_elements_by_tag_name('td')[2].text
#     print(annual_fires['acres'])
#     print("Scraping next row")
#     table.append(annual_fires)

# %%
# df = pd.DataFrame(table)
# df.head(100)

# %%
# df.dtypes

# %%
# df.to_csv("annual_fires.csv", index=False)

# %%
# df.year = df.year.astype('int', inplace=True)
# df.dtypes

# %%
# df.acres = df.acres.str.replace(',', '')

# %%
# df.acres = df.acres.str.replace('*', '')

# %%
# df.acres = df.acres.astype('int', inplace=True)
# df.dtypes

# %%
# df.fires = df.fires.str.replace(',', '').astype('int', inplace=True)
# df.dtypes

# %%
# df.to_csv("annual_fires.csv", index=False)

# %%
df = pd.read_csv("annual_fires.csv")

# %%
df.sort_values(by=['year']).plot(x='year', y='fires', kind='bar', figsize=(25,12), color='red')

# %%
df.sort_values(by=['year']).plot(x='year', y='acres', kind='bar', figsize=(25,12), color='red')

# %% [markdown]
# These trends are NOT at all what one would expect! However there's a note with the data that data collection was not standardized until 1983, so anything before that should not be compared to the rest of the data. There's an interesting story here on why historical data is so off. But, for now, to graph post-1983 data

# %%
df.sort_values(by=['year']).tail(35).plot(x='year', y='fires', kind='bar', figsize=(25,12), color='red')

# %% [markdown]
# There we go! That's the trend we were expecting...

# %%
df.sort_values(by=['year']).tail(35).plot(x='year', y='acres', kind='bar', figsize=(25,12), color='red')

# %%
df['avg_acres'] = df.acres / df.fires

# %%
df.sort_values(by=['year']).tail(35).plot(x='year', y='avg_acres', kind='bar', figsize=(25,12), color='red')

# %%
# driver = webdriver.Chrome()
# driver.get('https://www.nifc.gov/fireInfo/fireInfo_stats_lgFires.html')

# %%
# fire = driver.find_element_by_tag_name('tbody')
# print(fire)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="1b02c5f1363ecbc5848027b61c52abb8", element="0.10053382472290395-1")>

# %%
# fire.text
# Out:
# "Year Fire Name Location State Total Acres\n2004 Taylor Complex AK-TAS AK 1,305,592\n2006 East Amarillo Complex TX-TXS TX 907,245\n2017 NW Oklahoma Complex OK-OKS OK 779,292\n2007 Murphy Complex ID-TFD ID 652,016\n2009 Railbelt Complex AK-AKS AK 636,224\n2004 Eagle Complex AK-UYD AK 614,974\n1997 Inowak AK-AKS AK 610,000\n2012 Long Draw OR-VAD OR 557,628\n2004 Solstice Complex AK-UYD AK 547,505\n2011 Wallow AZ- ASF AZ 538,049\n2004 Boundary Fire AK-FAS AK 537,098\n2009 Minto Flats South AK-FAS AK 517,078\n2005 Southern Nevada Complex NV-LVD NV 508,751\n2002 Biscuit (formerly Florence) OR-SIF OR 500,068\n2015 Tanana Area Fires AK-TAD AK 498,043\n2002 Trimbly Creek OR-VAD OR 480,000\n2002 Rodeo/Chediski Complex AZ-FTA AZ 468,638\n2012 Holloway NV-WID NV 460,850\n2004 Central Complex AK-UYD AK 451,162\n2009 Crazy Mountain Complex AK-UYD AK 447,420\n2015 Ruby Area Fires AK-GAD AK 421,613\n2006 Eastern Oklahoma IA OK-OKS OK 413,964\n2014 Buzzard Complex OR-BUD OR 395,747\n2007 Big Turnaround Complex GA-OKR GA 386,722\n2016 Anderson Creek OK-OKS OK 367,740\n2007 Milford Flat UT-SWS UT 363,052\n1999 Dun Glen Complex NV-WID NV 361,658\n2002 Kraft Complex SD-SRA SD 351,000\n2009 Little Black One  AK-UYD AK 349,450\n2012 Mustang Complex ID-SCF ID 341,448\n2017 Perryton TX-TXS TX 318,156\n2012 Rush CA-NOD CA 315,577\n2011 Rock House TX-TFS TX 314,444\n2011 Honey Prairie GA-ONWR GA 309,200\n2010 Long Butte ID-TFD ID 306,113\n2007 Cascade Complex ID-BOF ID 302,376\n2007 East Zone Complex ID-PAF ID 300,022\n2012 Whitewater- Baldy NM-GNF NM 297,845\n1999 Sadler Complex NV-EKD NV 297,000\n2000 Valley Complex MT-BRF MT 292,070\n2004 Pingo AK-UYD AK 285,885\n2015 Soda ID-BOD ID 283,180\n2004 Winter Trail AK-UYD AK 279,865\n2003 Cedar CA-CNF CA 273,246\n2015 Sushgitit Hills AK-TAD AK 270,747\n2017 Thomas CA-VNC CA 270,000\n2017 Lodgepole Complex MT-MCD MT 270,000\n2004 Chicken Complex AK-TAS AK 257,720\n2002 Geskamina Lake AK-TAD A 257,549\n2013 Rim CA-STF CA 257,314\n2014 Calton Complex WA-NES WA 256,108\n2006 North Central Texas IA TX-TXS TX 250,942\n2012 Ash Creek MT-NCA MT 249,562\n2005 Cave Creek Complex AZ-TNF AZ 248,310\n2007 Zaca Two CA-LPF CA 240,207\n2006 Winters NV-WID NV 238,458\n2002 Reindeer AK-SWS A 227,800\n2006 Derby Fire MT-GNF MT 223,570\n2011 Horseshoe 2 SW AZ 222,954\n2006 Crystal ID-IFD ID 220,042\n2008 Glass Fire TX-TXS TX 219,556\n2017 Roosters Comb NV-NNS NV 218,380\n2015 North Star WA-COA WA 218,138\n2000 Clear Creek Complex ID-SCF ID 216,961\n2003 Needles WA-OWF WA 213,000\n2012 Kinyon Road ID-TFD ID 210,874\n1999 Battle Mountain Complex NV-BWD NV 208,031\n2013 Lime Hills AK-DOF AK 201,808\n2015 Holtnakatna AK-GAD AK 198,133\n2007 Witch CA-MVU CA 197,990\n2004 Wolf Creek AK-UYD AK 197,067\n2002 Minchumina Group AK-TAD AK 196,584\n2014 Funny River AK AK 195,858\n2005 Clover ID-TFD ID 192,846\n2000 Eastern Idaho Complex ID-IFD ID 192,450\n2008 Klamath Theater CA-KNF CA 192,038\n2000 Command 24 WA-SPD WA 192,000\n2017 Chetco Bar OR-RSF OR 191,125\n2006 Charleston Complex NV-EKD NV 190,421\n2016 Pioneer ID-BOF ID 188,404\n2000 SCF Wilderness ID-SCF ID 182,600\n2012 Halstead ID-SCF ID 181.948\n2007 Rowland ID-TFD ID 180,000\n2001 Lakeview Complex OR-FRF OR 179,400\n2016 Range 12 WA-SES WA 176,600\n2004 Camp Creek AK-DAS AK 175,815\n2011 Deaton Cole TX-TFS TX 175,000\n2010 Toklat AK-TAD AK 171,727\n2012 Rosebud Creek Complex MT-EAS MT 171,444\n1999 Corridor Complex NV-WID NV 171,600\n2005 Delamar NV-ELD NV 170,089\n2009 Big Creek AK-AFS AK 169,639\n2005 Beaver Creek AK-UYD AK 167,766\n2000 Zitziana AK-TAD AK 166,177\n2009 Titna River AK-TAD AK 164,542\n2009 Tonclonukna Creek AK-SWS AK 164,318\n2007 Winecup Complex NV-EKD NV 163,767\n2008 Basin Complex CA-LPF CA 162,818\n2006 Day CA-LPF CA 162,702\n2005 Chapman Creek AK-TAD AK 162,670\n2011 Cooper Mountain Ranch TX-TFS TX 162,625\n2012 Miller Homestead OR-BUD OR 160,853\n2007 Bugaboo Scrub Fire GA-OKR GA 160,727\n2009 Station CA-ANF CA 160,577\n2017 Rice Ridge MT-LNF MT 160,1 ...

# %%
# rows = fire.find_elements_by_tag_name('tr')[1:]
# table = []
# for row in rows:
#     sig_fires = {}
#     sig_fires['year'] = row.find_elements_by_tag_name('td')[0].text
#     print(sig_fires['year'])
#     sig_fires['fire_name'] = row.find_elements_by_tag_name('td')[1].text
#     print(sig_fires['fire_name'])
#     sig_fires['location'] = row.find_elements_by_tag_name('td')[2].text
#     print(sig_fires['location'])
#     sig_fires['state'] = row.find_elements_by_tag_name('td')[3].text
#     print(sig_fires['state'])
#     sig_fires['acres'] = row.find_elements_by_tag_name('td')[4].text
#     print(sig_fires['acres'])
#     print("Scraping next row")
#     table.append(sig_fires)
# Out:
# 2004
# Taylor Complex
# AK-TAS
# AK
# 1,305,592
# Scraping next row
# 2006
# East Amarillo Complex
# TX-TXS
# TX
# 907,245
# Scraping next row
# 2017
# NW Oklahoma Complex
# OK-OKS
# OK
# 779,292
# Scraping next row
# 2007
# Murphy Complex
# ID-TFD
# ID
# 652,016
# Scraping next row
# 2009
# Railbelt Complex
# AK-AKS
# AK
# 636,224
# Scraping next row
# 2004
# Eagle Complex
# AK-UYD
# AK
# 614,974
# Scraping next row
# 1997
# Inowak
# AK-AKS
# AK
# 610,000
# Scraping next row
# 2012
# Long Draw
# OR-VAD
# OR
# 557,628
# Scraping next row
# 2004
# Solstice Complex
# AK-UYD
# AK
# 547,505
# Scraping next row
# 2011
# Wallow
# AZ- ASF
# AZ
# 538,049
# Scraping next row
# 2004
# Boundary Fire
# AK-FAS
# AK
# 537,098
# Scraping next row
# 2009
# Minto Flats South
# AK-FAS
# AK
# 517,078
# Scraping next row
# 2005
# Southern Nevada Complex
# NV-LVD
# NV
# 508,751
# Scraping next row
# 2002
# Biscuit (formerly Florence)
# OR-SIF
# OR
# 500,068
# Scraping next row
# 2015
# Tanana Area Fires
# AK-TAD
# AK
# 498,043
# Scraping next row
# 2002
# Trimbly Creek
# OR-VAD
# OR
# 480,000
# Scraping next row
# 2002
# Rodeo/Chediski Complex
# AZ-FTA
# AZ
# 468,638
# Scraping next row
# 2012
# Holloway
# NV-WID
# NV
# 460,850
# Scraping next row
# 2004
# Central Complex
# AK-UYD
# AK
# 451,162
# Scraping next row
# 2009
# Crazy Mountain Complex
# AK-UYD
# AK
# 447,420
# Scraping next row
# 2015
# Ruby Area Fires
# AK-GAD
# AK
# 421,613
# Scraping next row
# 2006
# Eastern Oklahoma IA
# OK-OKS
# OK
# 413,964
# Scraping next row
# 2014
# Buzzard Complex
# OR-BUD
# OR
# 395,747
# Scraping next row
# 2007
# Big Turnaround Complex
# GA-OKR
# GA
# 386,722
# Scraping next row
# 2016
# Anderson Creek
# OK-OKS
# OK
# 367,740
# Scraping next row
# 2007
# Milford Flat
# UT-SWS
# UT
# 363,052
# Scraping next row
# 1999
# Dun Glen Complex
# NV-WID
# NV
# 361,658
# Scraping next row
# 2002
# Kraft Complex
# SD-SRA
# SD
# 351,000
# Scraping next row
# 2009
# Little Black One
# AK-UYD
# AK
# 349,450
# Scraping next row
# 2012
# Mustang Complex
# ID-SCF
# ID
# 341,448
# Scraping next row
# 2017
# Perryton
# TX-TXS
# TX
# 318,156
# Scraping next row
# 2012
# Rush
# CA-NOD
# CA
# 315,577
# Scraping next row
# 2011
# Rock House
# TX-TFS
# TX
# 314,444
# Scraping next row
# 2011
# Honey Prairie
# GA-ONWR
# GA
# 309,200
# Scraping next row
# 2010
# Long Butte
# ID-TFD
# ID
# 306,113
# Scraping next row
# 2007
# Cascade Complex
# ID-BOF
# ID
# 302,376
# Scraping next row
# 2007
# East Zone Complex
# ID-PAF
# ID
# 300,022
# Scraping next row
# 2012
# Whitewater- Baldy
# NM-GNF
# NM
# 297,845
# Scraping next row
# 1999
# Sadler Complex
# NV-EKD
# NV
# 297,000
# Scraping next row
# 2000
# Valley Complex
# MT-BRF
# MT
# 292,070
# Scraping next row
# 2004
# Pingo
# AK-UYD
# AK
# 285,885
# Scraping next row
# 2015
# Soda
# ID-BOD
# ID
# 283,180
# Scraping next row
# 2004
# Winter Trail
# AK-UYD
# AK
# 279,865
# Scraping next row
# 2003
# Cedar
# CA-CNF
# CA
# 273,246
# Scraping next row
# 2015
# Sushgitit Hills
# AK-TAD
# AK
# 270,747
# Scraping next row
# 2017
# Thomas
# CA-VNC
# CA
# 270,000
# Scraping next row
# 2017
# Lodgepole Complex
# MT-MCD
# MT
# 270,000
# Scraping next row
# 2004
# Chicken Complex
# AK-TAS
# AK
# 257,720
# Scraping next row
# 2002
# Geskamina Lake
# AK-TAD
# A
# 257,549
# Scraping next row
# 2013
# Rim
# CA-STF
# CA
# 257,314
# Scraping next row
# 2014
# Calton Complex
# WA-NES
# WA
# 256,108
# Scraping next row
# 2006
# North Central Texas IA
# TX-TXS
# TX
# 250,942
# Scraping next row
# 2012
# Ash Creek
# MT-NCA
# MT
# 249,562
# Scraping next row
# 2005
# Cave Creek Complex
# AZ-TNF
# AZ
# 248,310
# Scraping next row
# 2007
# Zaca Two
# CA-LPF
# CA
# 240,207
# Scraping next row
# 2006
# Winters
# NV-WID
# NV
# 238,458
# Scraping next row
# 2002
# Reindeer
# AK-SWS
# A
# 227,800
# Scraping next row
# 2006
# Derby Fire
# MT-GNF
# MT
# 223,570
# Scraping next row
# 2011
# Horseshoe 2
# SW
# AZ
# 222,954
# Scraping next row
# 2006
# Crystal
# ID-IFD
# ID
# 220,042
# Scraping next row
# 2008
# Glass Fire
# TX-TXS
# TX
# 219,556
# Scraping next row
# 2017
# Roosters Comb
# NV-NNS
# NV
# 218,380
# Scraping next row
# 2015
# North Star
# WA-COA
# WA
# 218,138
# Scraping next row
# 2000
# Clear Creek Complex
# ID-SCF
# ID
# 216,961
# Scraping next row
# 2003
# Needles
# WA-OWF
# WA
# 213,000
# Scraping next row
# 2012
# Kinyon Road
# ID-TFD
# ID
# 210,874
# Scraping next row
# 1999
# Battle Mountain Complex
# NV-BWD
# NV
# 208,031
# Scraping next row
# 2013
# Lime Hills
# AK-DOF
# AK
# 201,808
# Scraping next row
# 2015
# Holtnakatna
# AK-GAD
# AK
# 198,133
# Scraping next row
# 2007
# Witch
# CA-MVU
# CA
# 197,990
# Scraping next row
# 2004
# Wolf Creek
# AK-UYD
# AK
# 197,067
# Scraping next row
# 2002
# Minchumina Group
# AK-TAD
# AK
# 196,584
# Scraping next row
# 2014
# Funny River
# AK
# AK
# 195,858
# Scraping next row
# 2005
# Clover
# ID-TFD
# ID
# 192,846
# Scraping next row
# 2000
# Eastern Idaho Complex
# ID-IFD
# ID
# 192,450
# Scraping next row
# 2008
# Klamath Theater
# CA-KNF
# CA
# 192,038
# Scraping next row
# 2000
# Command 24
# WA-SPD
# WA
# 192,000
# Scraping next row
# 2017
# Chetco Bar
# OR-RSF
# OR
# 191,125
# Scraping next row
# 2006
# Charleston Complex
# NV-EKD
# NV
# 190,421
# Scraping next row
# 2016
# Pioneer
# ID-BOF
# ID
# 188,404
# Scraping next row
# 2000
# SCF Wilderness
# ID-SCF
# ID
# 182,600
# Scraping next row
# 2012
# Halstead
# ID-SCF
# ID
# 181.948
# Scraping next row
# 2007
# Rowland
# ID-TFD
# ID
# 180,000
# Scraping next row
# 2001
# Lakeview Complex
# OR-FRF
# OR
# 179,400
# Scraping next row
# 2016
# Range 12
# WA-SES
# WA
# 176,600
# Scraping next row
# 2004
# Camp Creek
# AK-DAS
# AK
# 175,815
# Scraping next row
# 2011
# Deaton Cole
# TX-TFS
# TX
# 175,000
# Scraping next row
# 2010
# Toklat
# AK-TAD
# AK
# 171,727
# Scraping next row
# 2012
# Rosebud Creek Complex
# MT-EAS
# MT
# 171,444
# Scraping next row
# 1999
# Corridor Complex
# NV-WID
# NV
# 171,600
# Scraping next row
# 2005
# Delamar
# NV-ELD
# NV
# 170,089
# Scraping next row
# 2009
# Big Creek
# AK-AFS
# AK
# 169,639
# Scraping next row
# 2005
# Beaver Creek
# AK-UYD
# AK
# 167,766
# Scraping next row
# 2000
# Zitziana
# AK-TAD
# AK
# 166,177
# Scraping next row
# 2009
# Titna River
# AK-TAD
# AK
# 164,542
# Scraping next row
# 2009
# Tonclonukna Creek
# AK-SWS
# AK
# 164,318
# Scraping next row
# 2007
# Winecup Complex
# NV-EKD
# NV
# 163,767
# Scraping next row
# 2008
# Basin Complex
# CA-LPF
# CA
# 162,818
# Scraping next row
# 2006
# Day
# CA-LPF
# CA
# 162,702
# Scraping next row
# 2005
# Chapman Creek
# AK-TAD
# AK
# 162,670
# Scraping next row
# 2011
# Cooper Mountain Ranch
# TX-TFS
# TX
# 162,625
# Scraping next row
# 2012
# Miller Homestead
# OR-BUD
# OR
# 160,853
# Scraping next row
# 2007
# Bugaboo Scrub Fire
# GA-OKR
# GA
# 160,727
# Scraping next row
# 2009
# Station
# CA-ANF
# CA
# 160,577
# Scraping next row
# 2017
# Rice Ridge
# MT-LNF
# MT
# 160,187
# Scraping next row
# 2007
# Elk Mountain
# ID-TFD
# ID
# 160,000
# Scraping next row
# 2017
# Four Seasons Complex
# NV-EKD
# NV
# 159,986
# Scraping next row
# 2011
# Wildcat
# TX-TFS
# TX
# 159,308
# Scraping next row
# 2015
# Aniak Complex
# AK-SWS
# AK
# 157,783
# Scraping next row
# 2013
# Moore Creek
# AK-DOF
# AK
# 157,747
# Scraping next row
# 2011
# Las Conchas
# NM-N6S
# NM
# 156,593
# Scraping next row
# 2017
# West Mims
# GA-OKR
# GA
# 152,515
# Scraping next row
# 2015
# Rough
# CA-SNF
# CA
# 151,623
# Scraping next row
# 2000
# Two Fork
# WA-SPD
# WA
# 151,000
# Scraping next row
# 2002
# McNally
# CA-SQF
# CA
# 150,696
# Scraping next row
# 2006
# Sheep
# NV-EKD
# NV
# 150,270
# Scraping next row
# 2013
# Pony Complex
# ID-BOD
# ID
# 149,384
# Scraping next row
# 2012
# Trinity Ridge
# ID-BOF
# ID
# 146,832
# Scraping next row
# 2005
# Meadow Valley
# NV-ELD
# NV
# 146,035
# Scraping next row
# 2015
# Okanogan Complex
# WA-OKF
# WA
# 145,282
# Scraping next row
# 1999
# Mule Butte
# ID-IFD
# ID
# 144,000
# Scraping next row
# 2015
# Rock
# AK-TAD
# AK
# 142,637
# Scraping next row
# 2012
# Flattop 2
# ID-TFD
# ID
# 140,954
# Scraping next row
# 1999
# Big Bar Complex
# CA-SHF
# CA
# 140,948
# Scraping next row
# 2007
# Egley Complex
# OR-BFZ
# OR
# 140,359
# Scraping next row
# 2013
# Silver
# NM-GNF
# NM
# 138,546
# Scraping next row
# 2002
# Hayman
# CO-PSF
# CO
# 137,760
# Scraping next row
# 2000
# Kate's Basin Complex
# WY-WRA
# WY
# 137,600
# Scraping next row
# 2007
# Antelope Complex
# NV-BMD
# NV
# 136,778
# Scraping next row
# 2017
# Lefors East
# TX-TXS
# TX
# 135,000
# Scraping next row
# 2014
# Happy Camp Complex
# CA-KNF
# CA
# 134,056
# Scraping next row
# 2016
# Soberanes
# CA-LPF
# CA
# 132,127
# Scraping next row
# 2013
# Elk Complex
# ID-BOF
# ID
# 131,258
# Scraping next row
# 2012
# Chalky
# MT-MCD
# MT
# 131,000
# Scraping next row
# 2003
# Missouri Breaks Complex
# MT-MCD
# MT
# 130,927
# Scraping next row
# 2006
# Parks Hwy
# AK-FAS
# AK
# 130,186
# Scraping next row
# 2015
# Isahultila
# AK-GAD
# AK
# 128,617
# Scraping next row
# 2017
# Diamond Creek
# WA-OWF
# WA
# 128,272
# Scraping next row
# 2011
# Pk Complex
# TX-TFS
# TX
# 126,734
# Scraping next row
# 2009
# Nowitna
# AK-AFS
# AK
# 126,582
# Scraping next row
# 1999
# Jungo Complex
# NV-WID
# NV
# 125,480
# Scraping next row
# 2009
# Wood River 1
# AK-AFS
# AK
# 125,382
# Scraping next row
# 2000
# Diamond Peak
# ID-PAF
# ID
# 125,000
# Scraping next row
# 2006
# Black Pulaski Complex
# MT-MCD
# MT
# 124,905
# Scraping next row
# 2002
# Blackjack Bay Complex
# GA-OKR
# GA
# 124,492
# Scraping next row
# 2000
# Bering Creek
# AK-TAD
# AK
# 122,994
# Scraping next row
# 2007
# Shower Bath Complex
# ID-SCF
# ID
# 122,600
# Scraping next row
# 2011
# Swenson
# TX-TFS
# TX
# 122,500
# Scraping next row
# 2016
# Hot Pot
# NV-EKD
# NV
# 122,292
# Scraping next row
# 2004
# Evansville
# AK-TAD
# AK
# 122,000
# Scraping next row
# 2006
# Pine Ridge Complex
# MT-SOS
# MT
# 121,210
# Scraping next row
# 2002
# Tool Box Complex
# OR-FAF
# OR
# 120,085
# Scraping next row
# 2004
# Willow
# AZ-TNF
# AZ
# 119,500
# Scraping next row
# 2006
# Oklahoma Fire Response
# OK-OKS
# OK
# 117,686
# Scraping next row
# 2006
# South End Complex
# OR-BUD
# OR
# 117,553
# Scraping next row
# 2005
# Boundary Creek
# AK-UYD
# AK
# 113,463
# Scraping next row
# 2016
# Alatna Complex
# AK-TAK
# AK
# 113,157
# Scraping next row
# 2006
# Tripod Complex
# WA-OWF
# WA
# 113,011
# Scraping next row
# 2013
# Beaver Creek
# ID-TFD
# ID
# 111,490
# Scraping next row
# 2015
# Sea
# AK-TAD
# AK
# 111,193
# Scraping next row
# 2011
# Indian Creek
# NV-NDF
# NV
# 110,827
# Scraping next row
# 2017
# Central LNU Complex
# CA-LNU
# CA
# 110,720
# Scraping next row
# 2015
# Canyon Creek Complex
# OR-MAF
# OR
# 110,261
# Scraping next row
# 2000
# Mule Dry
# WA-WFS
# WA
# 110,000
# Scraping next row
# 2013
# West Fork Complex
# AK-DOF
# AK
# 109,615
# Scraping next row
# 2010
# Jefferson
# ID-INL
# ID
# 109,436
# Scraping next row
# 2006
# Columbia Complex
# OR-UMF
# OR
# 109,259
# Scraping next row
# 2007
# Florida Bugaboo
# FL-FNF
# FL
# 108,574
# Scraping next row
# 2006
# Amazon
# NV-EKD
# NV
# 108,564
# Scraping next row
# 2003
# Simi Incident
# CA-VNC
# CA
# 108,304
# Scraping next row
# 2011
# High Cascades
# NW
# OR
# 108,154
# Scraping next row
# 2000
# Jackson Fire
# OR-VAD
# OR
# 108,000
# Scraping next row
# 2012
# Clay Springs
# UT-SCS
# UT
# 107,846
# Scraping next row
# 2005
# Sheenjek River
# AK-UYD
# AK
# 107,240
# Scraping next row
# 2001
# Survey Line
# AK- DOD
# AK
# 106,800
# Scraping next row
# 2008
# Iron & Alps Complexes
# CA-SHF
# CA
# 105,805
# Scraping next row
# 2011
# Southeast Texas Complex
# TX-TFS
# TX
# 104,818
# Scraping next row
# 2015
# Big Mud River 1
# AK-TAD
# AK
# 103,170
# Scraping next row
# 2008
# Dunn Mtn. Assist
# MT-SOS
# MT
# 102,383
# Scraping next row
# 2015
# Cornet-Windy Ridge
# OR-VAD
# OR
# 102,089
# Scraping next row
# 2007
# Rattlesnake
# ID-NPF
# ID
# 102,000
# Scraping next row
# 2011
# Donaldson
# SW
# NM
# 101,563
# Scraping next row
# 2009
# Rex Creek
# WF
# AK
# 101,150
# Scraping next row
# 2006
# Bar Complex
# CA-SHF
# CA
# 100,414
# Scraping next row
# 1999
# Kink
# AK-UYD
# AK
# 100,000
# Scraping next row
# 2000
# Maudlow/ Toston
# MT-CES
# MT
# 100,000
# Scraping next row
# 2002
# Vinasale
# AK-AKS
# AK
# 100,000
# Scraping next row

# %%
# df = pd.DataFrame(table)
# df.head()
# Out:
#        acres              fire_name location state  year
# 0  1,305,592  Taylor Complex         AK-TAS   AK    2004
# 1  907,245    East Amarillo Complex  TX-TXS   TX    2006
# 2  779,292    NW Oklahoma Complex    OK-OKS   OK    2017
# 3  652,016    Murphy Complex         ID-TFD   ID    2007
# 4  636,224    Railbelt Complex       AK-AKS   AK    2009

# %%
# df.to_csv("significant_fires.csv", index=False)
# df.head()
# Out:
#        acres              fire_name location state  year
# 0  1,305,592  Taylor Complex         AK-TAS   AK    2004
# 1  907,245    East Amarillo Complex  TX-TXS   TX    2006
# 2  779,292    NW Oklahoma Complex    OK-OKS   OK    2017
# 3  652,016    Murphy Complex         ID-TFD   ID    2007
# 4  636,224    Railbelt Complex       AK-AKS   AK    2009

# %%
# df.year = df.year.astype('int', inplace=True)
# df.dtypes
# Out:
# acres        object
# fire_name    object
# location     object
# state        object
# year         int64
# dtype: object

# %%
# df.acres = df.acres.str.replace(',', '')
# df.acres = df.acres.str.replace('.', '')
# df.acres = df.acres.astype('int', inplace=True)

# %%
# df.dtypes
# Out:
# acres        int64
# fire_name    object
# location     object
# state        object
# year         int64
# dtype: object

# %%
# df.to_csv("significant_fires.csv", index=False)

# %%
df2 = pd.read_csv("significant_fires.csv")

# %%
df2.sort_values(by=['year']).plot(x='year', y='acres', kind='bar', figsize=(25,12), color='red')

# %%
df2.groupby("year").acres.value_counts().unstack().reset_index().fillna(0).plot(x='year',kind='bar', stacked=True, legend=None, figsize=(25,12), color='red')

# %%
df2.groupby("year").fire_name.value_counts().unstack().reset_index().fillna(0).plot(x='year',kind='bar', stacked=True, legend=None, figsize=(25,12), color='red')

# %%
df.head()
# Out:
#       acres  fires  year   avg_acres
# 0  10026086  71499  2017  140.226940
# 1  5509995   67743  2016  81.336743
# 2  10125149  68151  2015  148.569339
# 3  3595613   63312  2014  56.791967
# 4  4319546   47579  2013  90.786818

# %%
df3 = pd.read_csv("nino_years.csv")

# %%
df3.head()
# Out:
#    AMJ  ASO  DJF  FMA  JAS  JFM  JJA  MAM  MJJ  NDJ  OND  SON  year    yr_avg
# 0 -1.1 -0.4 -1.5 -1.2 -0.4 -1.3 -0.5 -1.2 -0.9 -0.8 -0.6 -0.4  1950 -0.858333
# 1  0.4  1.0 -0.8 -0.2  0.9 -0.5  0.7  0.2  0.6  0.8  1.0  1.2  1951  0.441667
# 2  0.2  0.2  0.5  0.3  0.0  0.4 -0.1  0.3  0.0  0.1  0.0  0.1  1952  0.166667
# 3  0.8  0.8  0.4  0.6  0.7  0.6  0.7  0.7  0.8  0.8  0.8  0.8  1953  0.708333
# 4 -0.5 -0.9  0.8  0.0 -0.8  0.5 -0.6 -0.4 -0.5 -0.7 -0.7 -0.8  1954 -0.383333

# %%
df.to_csv("nino_years.csv", index=False)

# %%
plt.rcdefaults()
plt.rcParams.update({
    'lines.linewidth': 3,
    'legend.frameon' : False,
    'legend.borderaxespad' : 0,
    'axes.labelcolor' : 'black',
    'axes.labelsize': 'large',
    'axes.axisbelow': True,
    'axes.grid': False,
    'axes.titlepad' : 20,
    'axes.labelpad' : 5,
    'axes.edgecolor': 'white',
    'lines.solid_capstyle': 'round',
    'patch.linewidth': 0,
    'xtick.major.size': 10,
    'xtick.minor.size': 0,
    'ytick.major.size': 10,
    'ytick.minor.size': 0,
    'xtick.color' : 'black', 
    'ytick.color' : 'black',
    'font.size': 14.0,
    'font.serif' : 'Times New Roman',
    'font.family' : 'serif',
    'savefig.bbox' : 'tight',
    'figure.subplot.left': 0.08,
    'figure.subplot.right': 0.95,
    'figure.subplot.bottom': 0.07,
    'svg.fonttype': 'path',
    'pdf.fonttype': 42,
    'ps.fonttype': 42,
})

# %%
plt.rcParams.update({
    'axes.formatter.limits': [-20, 20]
})

from matplotlib.ticker import FuncFormatter

# STEP ONE: Build a function
# it should take value and pos
def with_words(value, pos):
    millions = int(value / 1000000)
    return "{} million".format(millions)

# STEP TWO: Use FuncFormatter with that function???
formatter = FuncFormatter(with_words)

fig0, ax0 = plt.subplots()
ax1 = ax0.twinx()

df.sort_values(by=['year']).tail(35).plot(x='year', y='acres', kind='bar', figsize=(25,12), legend=None, color='red', rot=0, ax=ax0)
df3.plot(kind='line',y='yr_avg',figsize=(25,12),legend=False, secondary_y=True, ax=ax1, color='black')

ax0.yaxis.set_major_formatter(formatter)

plt.savefig("fire-01.pdf")
plt.show()
plt.close()
